# %% [markdown]
# <a href="https://colab.research.google.com/github/yeyekang/MMoE-/blob/main/shared_bottom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/yeyekang/MMoE-
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Cloning into 'MMoE-'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 37 (delta 8), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (37/37), 18.98 MiB | 15.20 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/MMoE-/
# !ls
# Out:
# /content/MMoE-
# census-income.data.gz  LICENSE	   README.md
# census_income_demo.py  mmoe.ipynb  requirements.txt
# census-income.test.gz  mmoe.py	   shared-bottom.py

# %%
# !python shared-bottom.py
# Out:
# 2025-09-04 08:17:22.658113: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756973842.677867   31717 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756973842.683870   31717 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756973842.699639   31717 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
