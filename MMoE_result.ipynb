# %% [markdown]
# <a href="https://colab.research.google.com/github/yeyekang/MMoE-/blob/main/MMoE_result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/drawbridge/keras-mmoe.git
# Out:
# /content
# Cloning into 'keras-mmoe'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 71 (delta 20), reused 11 (delta 9), pack-reused 45 (from 1)
# Receiving objects: 100% (71/71), 9.34 MiB | 15.03 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# %cd /content/keras-mmoe
# !ls
# Out:
# /content/keras-mmoe
# census_income_demo.py  LICENSE	README.md	  synthetic_demo.py
# data		       mmoe.py	requirements.txt

# %%
# !python census_income_demo.py
# Out:
# 2025-09-05 08:46:33.441157: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757061993.460466    1074 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757061993.466356    1074 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757061993.481528    1074 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
